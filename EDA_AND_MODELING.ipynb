# %% [markdown]
# <a href="https://colab.research.google.com/github/xilola56/hospital-noshow-prediction/blob/main/EDA_AND_MODELING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
